# %%
### OPEN CSV AND OUTPUT SAMPLE

import csv
import random
import pandas as pd

path = 'MBB_year_by_year.csv'

df = pd.read_csv(path)

# %%
### sample 10 rows
df.sample(10)
# Out:
#                                       Team    Year  GamesPlayed  Win  Loss  \
# 2695                                Dexter  2015.0           22   10    12
# 36406                     Redford Thurston  2022.0            8    5     3
# 35724  Muskegon Western Michigan Christian  2021.0           10    4     6
# 15816                              Waldron  2019.0           14    5     9
# 24042              Taylor Trillium Academy  2021.0            4    3     1
# 61933                        East Kentwood  2014.0            3    3     0
# 59011                               Vassar  2012.0            4    3     1
# 56685             New Baltimore Anchor Bay  2020.0            1    0     1
# 1147                               Bronson  2013.0           20    1    19
# 73337                 Powers North Central  2020.0            2    0     2
#
#        Tie   Win_Pct  WinForfeit  LossForfeit  OvertimeWin  OvertimeLoss  \
# ...
