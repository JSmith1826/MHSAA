# %%
## Dependencies

import pandas as pd
from keplergl import KeplerGl
import os



## Table with overall stats for all years
stats = '../data/year_by_year_summary/overall/all_years_summary.csv'

## Team / School Info from the MHSAA Website
info = '../data/MHSAA_School_Data_with_Fields.csv'


## Load data into dataframes
stats_df = pd.read_csv(stats)
info_df = pd.read_csv(info)

## See the data

print(f'Overall Stats Table Shape: {stats_df.shape}')
print(f'Column Names: {stats_df.columns}')
      

print(f'MHSAA School Lookup Table Shape: {info_df.shape}')
print(f'Column Names: {info_df.columns}')
# Out:
# Overall Stats Table Shape: (715, 41)
# Column Names: Index(['teamName', 'teamId', 'team_record_count', 'playoff_games_played',
#        'playoff_W', 'playoff_L', 'playoff_runs_scored_total',
#        'playoff_runs_allowed_total', 'regular_season_games_played',
#        'regular_season_W', 'regular_season_L',
#        'regular_season_runs_scored_total', 'regular_season_runs_allowed_total',
#        'home_games_played', 'home_W', 'home_L', 'home_runs_scored_total',
#        'home_runs_allowed_total', 'away_games_played', 'away_W', 'away_L',
#        'away_runs_scored_total', 'away_runs_allowed_total', 'playoff_win_pct',
#        'regular_season_win_pct', 'home_win_pct', 'away_win_pct',
#        'playoff_run_diff_total', 'regular_season_run_diff_total',
#        'home_run_diff_total', 'away_run_diff_total', 'playoff_run_diff_mean',
#        'regular_season_run_diff_mean', 'home_run_diff_mean',
#        'away_run_diff_mean', 'playoff_run_diff_per_game',
#        'regular_season_run_diff_per_game', 'home_run_diff_per_game',
#        'away_run_diff_per_game', 'playoff_W_per_year', 'playoff_L_per_year'],
#       dtype='object')
# MHSAA School Lookup Table Shape: (4049, 40)
# Column Names: Index(['SchoolId', 'SportId', 'PopularName', 'ProperName', 'NickName',
#        'Colors', 'LeaugeName', 'LeaugeId', 'HeadCoach', 'PrimaryColorCode',
#        'ImagePath', 'Classification', 'Record', 'Enrollment', 'City', 'State',
#        'Address1', 'Address2', 'Zip', 'Phone', 'Fax', 'VanityUrl', 'MapURL',
#        'WebSite', 'IsMiddleSchool', 'ClassificationCalculationSteps',
#        'ClassificationCalculationStepsHtml', 'SportSeasonId', 'EnrollmentData',
#        'TicketUrl', 'OldSchoolId', 'SchoolNameWithId', 'Lat', 'Lng',
#        'Closest_Field_1', 'Closest_Field_2', 'Closest_Field_3', 'Distance_1',
#        'Distance_2', 'Distance_3'],
#       dtype='object')

# %%
### See how many matches I can get between the two tables

# Columns to match on (teamId, SchoolId)
# Pull data from the info_df table to stats_df table

# Merge the two tables
merged_df = pd.merge(stats_df, info_df, how='left', left_on='teamName', right_on='PopularName')

# See how many matches I got
print(f'Number of matches: {merged_df.shape[0]}')

## See some infor about the merged table
print(f'Merged Table Shape: {merged_df.shape}')
print(f'Column Names: {merged_df.columns}')

# See the data
merged_df.head()
# Out:
# Number of matches: 715
# Merged Table Shape: (715, 81)
# Column Names: Index(['teamName', 'teamId', 'team_record_count', 'playoff_games_played',
#        'playoff_W', 'playoff_L', 'playoff_runs_scored_total',
#        'playoff_runs_allowed_total', 'regular_season_games_played',
#        'regular_season_W', 'regular_season_L',
#        'regular_season_runs_scored_total', 'regular_season_runs_allowed_total',
#        'home_games_played', 'home_W', 'home_L', 'home_runs_scored_total',
#        'home_runs_allowed_total', 'away_games_played', 'away_W', 'away_L',
#        'away_runs_scored_total', 'away_runs_allowed_total', 'playoff_win_pct',
#        'regular_season_win_pct', 'home_win_pct', 'away_win_pct',
#        'playoff_run_diff_total', 'regular_season_run_diff_total',
#        'home_run_diff_total', 'away_run_diff_total', 'playoff_run_diff_mean',
#        'regular_season_run_diff_mean', 'home_run_diff_mean',
#        'away_run_diff_mean', 'playoff_run_diff_per_game',
#        'regular_season_run_diff_per_game', 'home_run_diff_per_game',
#        'away_run_diff_per_game', 'playoff_W_per_year', 'playoff_L_per_year',
#        'SchoolId', 'SportId', 'PopularName', 'ProperName', 'NickName',
#        'Colors', 'LeaugeName', 'LeaugeId', 'HeadCoach', 'PrimaryColorCode',
#        'ImagePath', 'Classification', 'Record', 'Enrollment', 'City', 'State',
#        'Address1', 'Address2', 'Zip', 'Phone', 'Fax', 'VanityUrl', 'MapURL',
#        'WebSite', 'IsMiddleSchool', 'ClassificationCalculationSteps',
#        'ClassificationCalculationStepsHtml', 'SportSeasonId', 'EnrollmentData',
#        'TicketUrl', 'OldSchoolId', 'SchoolNameWithId', 'Lat', 'Lng',
#        'Closest_Field_1', 'Closest_Field_2', 'Closest_Field_3', 'Distance_1',
#        'Distance_2', 'Distance_3'],
#       dtype='object')
#                    teamName   teamId  team_record_count  playoff_games_played  \
# 0  Ada Forest Hills Eastern  1976708                  6                    20
# 1                   Addison    95871                 10                    14
# 2                    Adrian    95800                 10                    21
# 3  Adrian Lenawee Christian    96297                 10                    21
# 4            Adrian Madison    95746                 10                    13
#
#    playoff_W  playoff_L  playoff_runs_scored_total  \
# 0       15.0        5.0                      117.0
# 1        4.0       10.0                       50.0
# 2       11.0       10.0                       91.0
# 3       11.0       10.0                      151.0
# 4        3.0       10.0                       45.0
#
#    playoff_runs_allowed_total  regular_season_games_played  regular_season_W  \
# 0                        40.0                         82.0              64.0
# 1                        84.0                        164.0              61.0
# 2                        99.0                        145.0              78.0
# 3                        99.0                         60.0              16.0
# 4                        88.0                        100.0              46.0
#
#    ...  OldSchoolId                 SchoolNameWithId        Lat        Lng  \
# 0  ...       4506.0  Ada Forest Hills Eastern (4506)  43.004934 -85.525979
# 1  ...       3037.0                   Addison (3037)  41.988315 -84.343935
# 2  ...       2294.0                    Adrian (2294)  41.909697 -84.045983
# 3  ...       8698.0  Adrian Lenawee Christian (8698)  41.908124 -84.081317
# 4  ...       1692.0            Adrian Madison (1692)  41.867936 -84.018374
#
#                         Closest_Field_1  \
# 0     Forrest Hills Eastern High School
# 1                            Addison HS
# 2                             Adrian HS
# 3           Adrian Lenawee Christian HS
# 4  Ann Arbor Greenhills HS? - Practice?
#
#                               Closest_Field_2  \
# 0       Grand Rapids Forest Hills Northern HS
# 1  Brooklyn Columbia Central HS - high_school
# 2                 Adrian Lenawee Christian HS
# 3                                   Adrian HS
# 4                                   Adrian HS
#
#                         Closest_Field_3  Distance_1  Distance_2  Distance_3
# 0      Grand Rapids Catholic Central HS    0.148290    2.769375    3.951781
# 1                             Onsted HS    0.249674    7.583523    7.860025
# 2  Ann Arbor Greenhills HS? - Practice?    0.225348    1.942878    3.371869
# 3  Ann Arbor Greenhills HS? - Practice?    0.132633    2.040508    4.480320
# 4           Adrian Lenawee Christian HS    0.243418    3.090306    4.389221
#
# [5 rows x 81 columns]

# %%
### Important columns to keep for the map plot

# School Name
# School City
# School Lat
# School Lng
# playoff_W
# regular_season_win_pct
# playoff_win_pct
# playoff_run_diff_mean
# regular_season_run_diff_mean
# Colors
# PrimaryColorCode
# LeaugeName
# LeaugeId
# PopularName
# NickName

# Create a new dataframe with only the columns I want
map_df = merged_df[['teamName', 'City', 'Lat', 'Lng', 'playoff_W', 
                    'regular_season_win_pct', 'playoff_win_pct', 
                    'playoff_run_diff_mean', 'regular_season_run_diff_mean', 
                    'Colors', 'PrimaryColorCode', 
                    'LeaugeName', 'LeaugeId', 'PopularName', 'NickName']]

## Change all column names to lower case
map_df.columns = map_df.columns.str.lower()

# rename lng to lon to work easier with the library
map_df.rename(columns={'lng': 'lon'}, inplace=True)

# See the data
map_df.head()
# Out:
# C:\Users\Justin\AppData\Local\Temp\ipykernel_15964\4204702510.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   map_df.rename(columns={'lng': 'lon'}, inplace=True)
#                    teamname     city        lat        lon  playoff_w  \
# 0  Ada Forest Hills Eastern      Ada  43.004934 -85.525979       15.0
# 1                   Addison  Addison  41.988315 -84.343935        4.0
# 2                    Adrian   Adrian  41.909697 -84.045983       11.0
# 3  Adrian Lenawee Christian   Adrian  41.908124 -84.081317       11.0
# 4            Adrian Madison   Adrian  41.867936 -84.018374        3.0
#
#    regular_season_win_pct  playoff_win_pct  playoff_run_diff_mean  \
# 0                0.780488         0.750000               3.850000
# 1                0.371951         0.285714              -2.428571
# 2                0.537931         0.523810              -0.380952
# 3                0.266667         0.523810               2.476190
# 4                0.460000         0.230769              -3.307692
#
#    regular_season_run_diff_mean                    colors primarycolorcode  \
# 0                      4.682927           Crimson & Black          #003366
# 1                     -1.725610               Black & Red          #003366
# 2                      0.668966        Royal Blue & White          #003366
# 3                     -4.983333  Royal Blue/White/Scarlet          #003366
# 4                      0.790000               Blue & Gold          #003366
#
#                               leaugename  leaugeid               popularname  \
# 0                         OK Conference     6963.0  Ada Forest Hills Eastern
# 1                    Cascades Conference    6900.0                   Addison
# 2                Southeastern Conference    6979.0                    Adrian
# 3  Southern Central Athletic Association    6980.0  Adrian Lenawee Christian
# 4                                    NaN       0.0            Adrian Madison
#
#    nickname
# 0     Hawks
# 1  Panthers
# 2    Maples
# 3   Cougars
# 4   Trojans

# %%
## Rename the map_df to df to make it easier to work with
df = map_df

# %%
# Create a new map
map_1 = KeplerGl(height=500)

# Add data to map
map_1.add_data(data=df, name='baseball_teams')
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
# Normalize 'playoff_W' to range [0, 10]
df['norm_playoff_W'] = df['playoff_w'] / df['playoff_w'].max() * 10

config = {
    'version': 'v1',
    'config': {
        'mapState': {
            'latitude': df['lat'].mean(),
            'longitude': df['lon'].mean(),
            'zoom': 6
        },
        'layers': [{
            'type': 'column',
            'dataId': 'baseball_teams',
            'columns': {
                'lat': 'lat',
                'lng': 'lon'
            },
            'is_3d': True,
            'visualChannels': {
                'heightField': 'norm_playoff_w',
                'heightScale': 'log'
            }
        }]
    }
}

map_1 = KeplerGl(height=700, widthe=700, config=config)
map_1.add_data(data=df, name='baseball_teams')
# map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# C:\Users\Justin\AppData\Local\Temp\ipykernel_15964\675956361.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['norm_playoff_W'] = df['playoff_w'] / df['playoff_w'].max() * 10

# %%
map_1
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'i1d6iqb', 'type': …
